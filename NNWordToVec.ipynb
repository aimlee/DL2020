# %%
import torch
from torch import nn
import torch.nn.functional as F
import pandas as pd
import re
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data = open('text.txt', 'r', encoding ='utf8').read()

# %%
print(data[:1000])
# Out:
# Алеся Казанцева
#
# Режиссёр сказал: одевайся теплее, тут холодно
#
#
#
# © Алеся Казанцева, 2019
#
# © Владимир Сахнов, иллюстрации, 2019
#
# © ООО «Издательство «Лайвбук», оформление, 2019
#
#
#
#
# «Алеся Петровна обладает уникальным умением. Она берет ничтожнейшую частицу здешнего бытия – пыль, козявку, жука, – и раздувает эту неприметную частицу, не фиксируемую нашим обычным взглядом, сначала в значимый предмет, потом в очень значимый предмет, потом в сверхзначимый предмет, потом в перл бытия, и, наконец, в высшую форму существования: в текст. Если бы Алеся Петровна взялась за какой-нибудь мю-мезон, за какой-нибудь завалящий кварк, она построила бы из него дополнительную Вселенную, хорошо оборудованную, исполненную смысла, красивую и тревожную, насквозь пронизанную юмором. И мы бы все с удовольствием в нее переехали!»
#
#     Татьяна Толстая, писательница
#
#
#
# «За свою жизнь, я прочел три книги. Букварь, синюю и книгу Алеси. Про меня гениально, про Слепакова похуже, но там и масштаб личности не тот. А в ц

# %%
data = re.sub(r'[\d\t,.?!-]','', data).split('\n')
print(data[:10000])
# Out:
# ['Алеся Казанцева', '', 'Режиссёр сказал: одевайся теплее тут холодно', '', '', '', '© Алеся Казанцева ', '', '© Владимир Сахнов иллюстрации ', '', '© ООО «Издательство «Лайвбук» оформление ', '', '', '', '', '«Алеся Петровна обладает уникальным умением Она берет ничтожнейшую частицу здешнего бытия – пыль козявку жука – и раздувает эту неприметную частицу не фиксируемую нашим обычным взглядом сначала в значимый предмет потом в очень значимый предмет потом в сверхзначимый предмет потом в перл бытия и наконец в высшую форму существования: в текст Если бы Алеся Петровна взялась за какойнибудь мюмезон за какойнибудь завалящий кварк она построила бы из него дополнительную Вселенную хорошо оборудованную исполненную смысла красивую и тревожную насквозь пронизанную юмором И мы бы все с удовольствием в нее переехали»', '', '    Татьяна Толстая писательница', '', '', '', '«За свою жизнь я прочел три книги Букварь синюю и книгу Алеси Про меня гениально про Слепакова похуже но там и масштаб личности не тот А в целом бумага мягкая шрифт крупный читается легко»', '', '    Дмитрий Нагиев актер телеведущий', '', '', '', '«Я написал три отзыва выберите сами какой лучше', '', ' Алеся Казанцева – феномен российской литературы  века Как ее только не называли критики – «Довлатов в юбке» «Марк Твен без пениса» «Лев Толстой коротких форм» «Достоевский без бороды» «ТЭФИ под трамалом» «Пушкин лучше» «Че там дальше» Все эти определения безусловно точны но они не отражают самого главного Потому что самое главное отразить очень сложно Это не удается практически никому Я например даже пробовать не буду Если вы держите в руках эту книгу значит вы – либо родственник или друг Алеси либо сама Алеся Купите эту книгу и вам не придется стыдливо прятать глаза встречаясь с белокурой бестией на съемочной площадке Деньги пойдут на прокорм двоих карапузов и оплату вайфая', '', '', '', ' Я не люблю читать Точнее люблю но мне лень Пока распробуешь автора пока дойдешь до завязки пока пробьешься сквозь частокол метафор и синекдох… да ну его на фиг Еще меньше я люблю читать современную литературу Еще меньше – современную российскую литературу Совсем не люблю читать фейсбук Ненавижу лайкать Потому что как только лайкнешь человека надо его дальше либо лайкать либо не лайкать А я не хочу этой глупой ненужной ответственности А вот Алесю я читать люблю И лайкать тоже Совершенно искренне Мне ведь от нее ничего не надо Замужняя рожавшая баба мужа любит как второй режиссер конечно профессиональная но не незаменимая Сценарий ее писать не заставишь – пообещает и сольется Словом кроме чистого творчества ловить там нечего И это – прекрасно Я рад что у Алеси выходит книга Жалко только что я уже все это читал А тем кто не читал очень рекомендую', '', '', '', ' У меня на фейсбуке около пяти тысяч друзей Потому что когда фейсбук только появился я принимал всех кто стучались Потом я заметил что моя лента состоит из безудержного и немыслимого потока говна По закону сообщающихся сосудов оно перетекало из фейсбука в мою голову Тогда я начал всех блокировать Сначала заблокировал незнакомых «друзей» Это было сука очень тяжело и долго Но я справился Затем пошел по знакомым ибо они тоже какали в мозг своими бесконечными хаотичными перепостами Хочу сказать что я – человек увлекающийся Когда я заблокировал двух родных дядь маму и папу я понял что у меня осталось три незаблокированных человека Один кинокритик просто чтобы знать что там новое выходит Алеся Казанцева и еще одна остроумная писательница но ее фамилию я здесь называть не буду поскольку речь сейчас об Алесе Алеся – крутая Мне смешно то что она пишет и то как она пишет А если не смешно то интересно Она остроумная добрая и честная Когда она бегала по съемочной площадке на фильме «Яйца судьбы» где мы познакомились и на всех орала она мне сразу понравилась самоотдачей и неравнодушием Она сумела перенести это в свое творчество В ее интонациях нет истерики но гдето глубоко внутри слышится пронзительное «помогите» вызванное вездесущим экзистенц ...

# %%
def tokenize_data(data):
    tokens = [x.split() for x in data]
    return tokens

tokenized_data = tokenize_data(data)
print(tokenized_data)
# Out:
# [['Алеся', 'Казанцева'], [], ['Режиссёр', 'сказал:', 'одевайся', 'теплее', 'тут', 'холодно'], [], [], [], ['©', 'Алеся', 'Казанцева'], [], ['©', 'Владимир', 'Сахнов', 'иллюстрации'], [], ['©', 'ООО', '«Издательство', '«Лайвбук»', 'оформление'], [], [], [], [], ['«Алеся', 'Петровна', 'обладает', 'уникальным', 'умением', 'Она', 'берет', 'ничтожнейшую', 'частицу', 'здешнего', 'бытия', '–', 'пыль', 'козявку', 'жука', '–', 'и', 'раздувает', 'эту', 'неприметную', 'частицу', 'не', 'фиксируемую', 'нашим', 'обычным', 'взглядом', 'сначала', 'в', 'значимый', 'предмет', 'потом', 'в', 'очень', 'значимый', 'предмет', 'потом', 'в', 'сверхзначимый', 'предмет', 'потом', 'в', 'перл', 'бытия', 'и', 'наконец', 'в', 'высшую', 'форму', 'существования:', 'в', 'текст', 'Если', 'бы', 'Алеся', 'Петровна', 'взялась', 'за', 'какойнибудь', 'мюмезон', 'за', 'какойнибудь', 'завалящий', 'кварк', 'она', 'построила', 'бы', 'из', 'него', 'дополнительную', 'Вселенную', 'хорошо', 'оборудованную', 'исполненную', 'смысла', 'красивую', 'и', 'тревожную', 'насквозь', 'пронизанную', 'юмором', 'И', 'мы', 'бы', 'все', 'с', 'удовольствием', 'в', 'нее', 'переехали»'], [], ['Татьяна', 'Толстая', 'писательница'], [], [], [], ['«За', 'свою', 'жизнь', 'я', 'прочел', 'три', 'книги', 'Букварь', 'синюю', 'и', 'книгу', 'Алеси', 'Про', 'меня', 'гениально', 'про', 'Слепакова', 'похуже', 'но', 'там', 'и', 'масштаб', 'личности', 'не', 'тот', 'А', 'в', 'целом', 'бумага', 'мягкая', 'шрифт', 'крупный', 'читается', 'легко»'], [], ['Дмитрий', 'Нагиев', 'актер', 'телеведущий'], [], [], [], ['«Я', 'написал', 'три', 'отзыва', 'выберите', 'сами', 'какой', 'лучше'], [], ['Алеся', 'Казанцева', '–', 'феномен', 'российской', 'литературы', 'века', 'Как', 'ее', 'только', 'не', 'называли', 'критики', '–', '«Довлатов', 'в', 'юбке»', '«Марк', 'Твен', 'без', 'пениса»', '«Лев', 'Толстой', 'коротких', 'форм»', '«Достоевский', 'без', 'бороды»', '«ТЭФИ', 'под', 'трамалом»', '«Пушкин', 'лучше»', '«Че', 'там', 'дальше»', 'Все', 'эти', 'определения', 'безусловно', 'точны', 'но', 'они', 'не', 'отражают', 'самого', 'главного', 'Потому', 'что', 'самое', 'главное', 'отразить', 'очень', 'сложно', 'Это', 'не', 'удается', 'практически', 'никому', 'Я', 'например', 'даже', 'пробовать', 'не', 'буду', 'Если', 'вы', 'держите', 'в', 'руках', 'эту', 'книгу', 'значит', 'вы', '–', 'либо', 'родственник', 'или', 'друг', 'Алеси', 'либо', 'сама', 'Алеся', 'Купите', 'эту', 'книгу', 'и', 'вам', 'не', 'придется', 'стыдливо', 'прятать', 'глаза', 'встречаясь', 'с', 'белокурой', 'бестией', 'на', 'съемочной', 'площадке', 'Деньги', 'пойдут', 'на', 'прокорм', 'двоих', 'карапузов', 'и', 'оплату', 'вайфая'], [], [], [], ['Я', 'не', 'люблю', 'читать', 'Точнее', 'люблю', 'но', 'мне', 'лень', 'Пока', 'распробуешь', 'автора', 'пока', 'дойдешь', 'до', 'завязки', 'пока', 'пробьешься', 'сквозь', 'частокол', 'метафор', 'и', 'синекдох…', 'да', 'ну', 'его', 'на', 'фиг', 'Еще', 'меньше', 'я', 'люблю', 'читать', 'современную', 'литературу', 'Еще', 'меньше', '–', 'современную', 'российскую', 'литературу', 'Совсем', 'не', 'люблю', 'читать', 'фейсбук', 'Ненавижу', 'лайкать', 'Потому', 'что', 'как', 'только', 'лайкнешь', 'человека', 'надо', 'его', 'дальше', 'либо', 'лайкать', 'либо', 'не', 'лайкать', 'А', 'я', 'не', 'хочу', 'этой', 'глупой', 'ненужной', 'ответственности', 'А', 'вот', 'Алесю', 'я', 'читать', 'люблю', 'И', 'лайкать', 'тоже', 'Совершенно', 'искренне', 'Мне', 'ведь', 'от', 'нее', 'ничего', 'не', 'надо', 'Замужняя', 'рожавшая', 'баба', 'мужа', 'любит', 'как', 'второй', 'режиссер', 'конечно', 'профессиональная', 'но', 'не', 'незаменимая', 'Сценарий', 'ее', 'писать', 'не', 'заставишь', '–', 'пообещает', 'и', 'сольется', 'Словом', 'кроме', 'чистого', 'творчества', 'ловить', 'там', 'нечего', 'И', 'это', '–', 'прекрасно', 'Я', 'рад', 'что', 'у', 'Алеси', 'выходит', 'книга', 'Жалко', 'только', 'что', 'я', 'уже', 'все', 'это', 'читал', 'А', 'тем', 'кто', 'не', 'читал', 'очень', 'рекомендую'], [], [], [], ['У', 'меня', 'на', 'фейсбуке', 'около', 'пяти' ...

# %%
vocabulary = []
for sentence in tokenized_data:
    for token in sentence:
        if token not in vocabulary:
            vocabulary.append(token)

word2idx = {w: idx for (idx, w) in enumerate(vocabulary)}
idx2word = {idx: w for (idx, w) in enumerate(vocabulary)}

vocabulary_size = len(vocabulary)

# %%
word2idx
# Out:
# {'Алеся': 0,
#  'Казанцева': 1,
#  'Режиссёр': 2,
#  'сказал:': 3,
#  'одевайся': 4,
#  'теплее': 5,
#  'тут': 6,
#  'холодно': 7,
#  '©': 8,
#  'Владимир': 9,
#  'Сахнов': 10,
#  'иллюстрации': 11,
#  'ООО': 12,
#  '«Издательство': 13,
#  '«Лайвбук»': 14,
#  'оформление': 15,
#  '«Алеся': 16,
#  'Петровна': 17,
#  'обладает': 18,
#  'уникальным': 19,
#  'умением': 20,
#  'Она': 21,
#  'берет': 22,
#  'ничтожнейшую': 23,
#  'частицу': 24,
#  'здешнего': 25,
#  'бытия': 26,
#  '–': 27,
#  'пыль': 28,
#  'козявку': 29,
#  'жука': 30,
#  'и': 31,
#  'раздувает': 32,
#  'эту': 33,
#  'неприметную': 34,
#  'не': 35,
#  'фиксируемую': 36,
#  'нашим': 37,
#  'обычным': 38,
#  'взглядом': 39,
#  'сначала': 40,
#  'в': 41,
#  'значимый': 42,
#  'предмет': 43,
#  'потом': 44,
#  'очень': 45,
#  'сверхзначимый': 46,
#  'перл': 47,
#  'наконец': 48,
#  'высшую': 49,
#  'форму': 50,
#  'существования:': 51,
#  'текст': 52,
#  'Если': 53,
#  'бы': 54,
#  'взялась': 55,
#  'за': 56,
#  'какойнибудь': 57,
#  'мюмезон': 58,
#  'завалящий': 59,
#  'кварк': 60,
#  'она': 61,
#  'построила': 62,
#  'из': 63,
#  'него': 64,
#  'дополнительную': 65,
#  'Вселенную': 66,
#  'хорошо': 67,
#  'оборудованную': 68,
#  'исполненную': 69,
#  'смысла': 70,
#  'красивую': 71,
#  'тревожную': 72,
#  'насквозь': 73,
#  'пронизанную': 74,
#  'юмором': 75,
#  'И': 76,
#  'мы': 77,
#  'все': 78,
#  'с': 79,
#  'удовольствием': 80,
#  'нее': 81,
#  'переехали»': 82,
#  'Татьяна': 83,
#  'Толстая': 84,
#  'писательница': 85,
#  '«За': 86,
#  'свою': 87,
#  'жизнь': 88,
#  'я': 89,
#  'прочел': 90,
#  'три': 91,
#  'книги': 92,
#  'Букварь': 93,
#  'синюю': 94,
#  'книгу': 95,
#  'Алеси': 96,
#  'Про': 97,
#  'меня': 98,
#  'гениально': 99,
#  'про': 100,
#  'Слепакова': 101,
#  'похуже': 102,
#  'но': 103,
#  'там': 104,
#  'масштаб': 105,
#  'личности': 106,
#  'тот': 107,
#  'А': 108,
#  'целом': 109,
#  'бумага': 110,
#  'мягкая': 111,
#  'шрифт': 112,
#  'крупный': 113,
#  'читается': 114,
#  'легко»': 115,
#  'Дмитрий': 116,
#  'Нагиев': 117,
#  'актер': 118,
#  'телеведущий': 119,
#  '«Я': 120,
#  'написал': 121,
#  'отзыва': 122,
#  'выберите': 123,
#  'сами': 124,
#  'какой': 125,
#  'лучше': 126,
#  'феномен': 127,
#  'российской': 128,
#  'литературы': 129,
#  'века': 130,
#  'Как': 131,
#  'ее': 132,
#  'только': 133,
#  'называли': 134,
#  'критики': 135,
#  '«Довлатов': 136,
#  'юбке»': 137,
#  '«Марк': 138,
#  'Твен': 139,
#  'без': 140,
#  'пениса»': 141,
#  '«Лев': 142,
#  'Толстой': 143,
#  'коротких': 144,
#  'форм»': 145,
#  '«Достоевский': 146,
#  'бороды»': 147,
#  '«ТЭФИ': 148,
#  'под': 149,
#  'трамалом»': 150,
#  '«Пушкин': 151,
#  'лучше»': 152,
#  '«Че': 153,
#  'дальше»': 154,
#  'Все': 155,
#  'эти': 156,
#  'определения': 157,
#  'безусловно': 158,
#  'точны': 159,
#  'они': 160,
#  'отражают': 161,
#  'самого': 162,
#  'главного': 163,
#  'Потому': 164,
#  'что': 165,
#  'самое': 166,
#  'главное': 167,
#  'отразить': 168,
#  'сложно': 169,
#  'Это': 170,
#  'удается': 171,
#  'практически': 172,
#  'никому': 173,
#  'Я': 174,
#  'например': 175,
#  'даже': 176,
#  'пробовать': 177,
#  'буду': 178,
#  'вы': 179,
#  'держите': 180,
#  'руках': 181,
#  'значит': 182,
#  'либо': 183,
#  'родственник': 184,
#  'или': 185,
#  'друг': 186,
#  'сама': 187,
#  'Купите': 188,
#  'вам': 189,
#  'придется': 190,
#  'стыдливо': 191,
#  'прятать': 192,
#  'глаза': 193,
#  'встречаясь': 194,
#  'белокурой': 195,
#  'бестией': 196,
#  'на': 197,
#  'съемочной': 198,
#  'площадке': 199,
#  'Деньги': 200,
#  'пойдут': 201,
#  'прокорм': 202,
#  'двоих': 203,
#  'карапузов': 204,
#  'оплату': 205,
#  'вайфая': 206,
#  'люблю': 207,
#  'читать': 208,
#  'Точнее': 209,
#  'мне': 210,
#  'лень': 211,
#  'Пока': 212,
#  'распробуешь': 213,
#  'автора': 214,
#  'пока': 215,
#  'дойдешь': 216,
#  'до': 217,
#  'завязки': 218,
#  'пробьешься': 219,
#  'сквозь': 220,
#  'частокол': 221,
#  'метафор': 222,
#  'синекдох…': 223,
#  'да': 224,
#  'ну': 225,
#  'его': 226,
#  'фиг': 227,
#  'Еще': 228,
#  'меньше': 229,
#  'современную': 230,
#  'литературу': 231,
#  'российскую': 232,
#  'Совсем': 233,
#  'фейсбук': 234,
#  'Ненавижу': 235,
#  'лайкать': 236,
#  'как': 237,
#  'лайкнешь': 238,
#  'человека': 239,
#  'надо': 240,
#  'дальше': 241,
#  'хочу': 242,
#  'этой': 243,
#  'глупой': 244,
#  'ненужной': 245,
#  'ответственности': 246,
#  'вот': 247,
#  'Алесю': 248,
#  'тоже': 249,
#  'Совершенно': 250,
#  'искренне': 251,
#  'Мне': 252,
#  'ведь': 253,
#  'от': 254,
#  'ничего': 255,
#  'Замужняя': 256,
#  'рожавшая': 257,
#  'баба': 258,
#  'мужа': 259,
#  'любит': 260,
#  'второй': 261,
#  'режиссер': 262,
#  'конечно': 263,
#  'профессиональная': 264,
#  'незаменимая': 265,
#  'Сценарий': 266,
#  'писать': 267,
#  'заставишь': 268,
#  'пообещает': 269,
#  'сольется': 270,
#  'Словом': 271,
#  'кроме': 272,
#  'чистого': 273,
#  'творчества': 274,
#  'ловить': 275,
#  'нечего': 276,
#  'это': 277,
#  'прекрасно': 278,
#  'рад': 279,
#  'у': 280,
#  'выходит': 281,
#  'книга': 282,
#  'Жалко': 283,
#  'уже': 284,
#  'читал': 285,
#  'тем': 286,
#  'кто': 287,
#  'рекомендую': 288,
#  'У': 289,
#  'фейсбуке': 290,
#  'около': 291,
#  'пяти': 292,
#  'тысяч': 293,
#  'друзей': 294,
#  'когда': 295,
#  'появился': 296,
#  'принимал': 297,
#  'всех': 298,
#  'стучались': 299,
#  'Потом': 300,
#  'заметил': 301,
#  'моя': 302,
#  'лента': 303,
#  'состоит': 304,
#  'безудержного': 305,
#  'немыслимого': 306,
#  'потока': 307,
#  'говна': 308,
#  'По': 309,
#  'закону': 310,
#  'сообщающихся': 311,
#  'сосудов': 312,
#  'оно': 313,
#  'перетекало': 314,
#  'фейсбука': 315,
#  'мою': 316,
#  'голову': 317,
#  'Тогда': 318,
#  'начал': 319,
#  'блокировать': 320,
#  'Сначала': 321,
#  'заблокировал': 322,
#  'незнакомых': 323,
#  '«друзей»': 324,
#  'было': 325,
#  'сука': 326,
#  'тяжело': 327,
#  'долго': 328,
#  'Но': 329,
#  'справился': 330,
#  'Затем': 331,
#  'пошел': 332,
#  'по': 333,
#  'знакомым': 334,
#  'ибо': 335,
#  'какали': 336,
#  'мозг': 337,
#  'своими': 338,
#  'бесконечными': 339,
#  'хаотичными': 340,
#  'перепостами': 341,
#  'Хочу': 342,
#  'сказать': 343,
#  'человек': 344,
#  'увлекающийся': 345,
#  'Когда': 346,
#  'двух': 347,
#  'родных': 348,
#  'дядь': 349,
#  'маму': 350,
#  'папу': 351,
#  'понял': 352,
#  'осталось': 353,
#  'незаблокированных': 354,
#  'Один': 355,
#  'кинокритик': 356,
#  'просто': 357,
#  'чтобы': 358,
#  'знать': 359,
#  'новое': 360,
#  'еще': 361,
#  'одна': 362,
#  'остроумная': 363,
#  'фамилию': 364,
#  'здесь': 365,
#  'называть': 366,
#  'поскольку': 367,
#  'речь': 368,
#  'сейчас': 369,
#  'об': 370,
#  'Алесе': 371,
#  'крутая': 372,
#  'смешно': 373,
#  'то': 374,
#  'пишет': 375,
#  'если': 376,
#  'интересно': 377,
#  'добрая': 378,
#  'честная': 379,
#  'бегала': 380,
#  'фильме': 381,
#  '«Яйца': 382,
#  'судьбы»': 383,
#  'где': 384,
#  'познакомились': 385,
#  'орала': 386,
#  'сразу': 387,
#  'понравилась': 388,
#  'самоотдачей': 389,
#  'неравнодушием': 390,
#  'сумела': 391,
#  'перенести': 392,
#  'свое': 393,
#  'творчество': 394,
#  'В': 395,
#  'интонациях': 396,
#  'нет': 397,
#  'истерики': 398,
#  'гдето': 399,
#  'глубоко': 400,
#  'внутри': 401,
#  'слышится': 402,
#  'пронзительное': 403,
#  '«помогите»': 404,
#  'вызванное': 405,
#  'вездесущим': 406,
#  'экзистенциальным': 407,
#  'маразмом': 408,
#  'те': 409,
#  'далекие': 410,
#  'времена': 411,
#  'подумать': 412,
#  'мог': 413,
#  'писатель': 414,
#  'давно': 415,
#  'подкатываю': 416,
#  'к': 417,
#  'ней': 418,
#  'яйца': 419,
#  '(уже': 420,
#  'судьбы)': 421,
#  'предложением': 422,
#  'написать': 423,
#  'сценарий': 424,
#  'зараза': 425,
#  'сливается': 426,
#  'подписался': 427,
#  'Кашина': 428,
#  'Навального': 429,
#  'через': 430,
#  'два': 431,
#  'дня': 432,
#  'отписался': 433,
#  'отписываюсь': 434,
#  'читал»': 435,
#  'Семен': 436,
#  'Слепаков': 437,
#  '«Когда': 438,
#  'обнаружила': 439,
#  'ЖЖ': 440,
#  'журнал': 441,
#  'Петровны': 442,
#  'была': 443,
#  'счастлива': 444,
#  'так…': 445,
#  'поздно': 446,
#  'писала': 447,
#  'лет': 448,
#  'хорошим': 449,
#  'сериалом:': 450,
#  'серий': 451,
#  'накопилось': 452,
#  'достаточно': 453,
#  'опасности': 454,
#  'вдруг': 455,
#  'закончится': 456,
#  'самом': 457,
#  'интересном': 458,
#  'месте': 459,
#  'будет': 460,
#  'мучительно': 461,
#  'ждать': 462,
#  'продолжения': 463,
#  'читала': 464,
#  'ночам': 465,
#  'хохотала': 466,
#  'так': 467,
#  'результате': 468,
#  'муж': 469,
#  'временно': 470,
#  'переместился': 471,
#  'диван': 472,
#  'вытерпев': 473,
#  'моего': 474,
#  'хрюканья': 475,
#  'всхлипываний': 476,
#  'мелкой': 477,
#  'тряски': 478,
#  'боком': 479,
#  'Наш': 480,
#  'брак': 481,
#  'устоял': 482,
#  'оказался': 483,
#  'большим': 484,
#  'ударом': 485,
#  'Казанцеву': 486,
#  'Дрожащими': 487,
#  'пальцами': 488,
#  'замирая': 489,
#  'восторга': 490,
#  'прыщавый': 491,
#  'подросток': 492,
#  'набрала': 493,
#  'ей': 494,
#  'комментарий': 495,
#  'который': 496,
#  'ответила': 497,
#  'моему': 498,
#  'удивлению': 499,
#  'менее': 500,
#  'восторженно': 501,
#  '(хотя': 502,
#  'казалось': 503,
#  'бы:': 504,
#  'ОНА': 505,
#  'а': 506,
#  'я):': 507,
#  '«мол': 508,
#  'потрясена': 509,
#  'пишете': 510,
#  'пошла': 511,
#  'помыла»': 512,
#  'был': 513,
#  'мой': 514,
#  'шанс': 515,
#  'момент': 516,
#  'раз': 517,
#  'недавно': 518,
#  'стала': 519,
#  'счастливой': 520,
#  'истерзанной': 521,
#  'матерью': 522,
#  'прекрасного': 523,
#  'Степана': 524,
#  'Бессонница': 525,
#  'сделала': 526,
#  'доверчивой': 527,
#  'обстоятельство': 528,
#  'позволило': 529,
#  'легко': 530,
#  'заловить': 531,
#  'свои': 532,
#  'сети': 533,
#  'уверена': 534,
#  'провинциальная': 535,
#  'смекалка': 536,
#  'помогла': 537,
#  'окрутить': 538,
#  'наивную': 539,
#  'москвичку)': 540,
#  'Мы': 541,
#  'перешли': 542,
#  'комментариев': 543,
#  'личку': 544,
#  'опытная': 545,
#  'мать': 546,
#  'детей': 547,
#  'безостановочно': 548,
#  'давала': 549,
#  'разнообразные': 550,
#  'советы': 551,
#  'обмен': 552,
#  'гомерически': 553,
#  'смешные': 554,
#  'монологи': 555,
#  'которые': 556,
#  'теперь': 557,
#  'непосредственно': 558,
#  'обращаясь': 559,
#  'ко': 560,
#  'Несчастная': 561,
#  'подозревала': 562,
#  'о': 563,
#  'моей': 564,
#  'корысти': 565,
#  'знала': 566,
#  'талантлива': 567,
#  'каждом': 568,
#  'своем': 569,
#  'слове': 570,
#  'движении': 571,
#  'поступке': 572,
#  'С': 573,
#  'тех': 574,
#  'пор': 575,
#  'сменили': 576,
#  'мессенджер': 577,
#  'ФБ': 578,
#  'Ватсап': 579,
#  'Телеграм': 580,
#  'снова': 581,
#  'эпистолярный': 582,
#  'роман': 583,
#  'длится': 584,
#  'когданибудь': 585,
#  'издадут': 586,
#  'отдельным': 587,
#  'собранием': 588,
#  'сочинений': 589,
#  'переписываемся': 590,
#  'почти': 591,
#  'ежедневно': 592,
#  'этот': 593,
#  'бабла': 594,
#  'заработаю': 595,
#  'Цинично': 596,
#  'воспользовавшись': 597,
#  'этим': 598,
#  'барнаульским': 599,
#  'самородком': 600,
#  '(ха': 601,
#  'думает': 602,
#  'москвичек': 603,
#  'облапошить)': 604,
#  'Успех': 605,
#  'многотомнику': 606,
#  'обеспечен': 607,
#  'знаю': 608,
#  'точно': 609,
#  'попрежнему': 610,
#  'хрюкаю': 611,
#  'всхлипываю': 612,
#  'днем': 613,
#  'вечером': 614,
#  'читаю': 615,
#  'сообщения': 616,
#  'Мой': 617,
#  'вернулся': 618,
#  'дивана': 619,
#  'обратно': 620,
#  'кровать': 621,
#  'убедившись': 622,
#  'угрозы': 623,
#  'шантаж': 624,
#  'бессмысленны': 625,
#  'ему': 626,
#  'както': 627,
#  'приспособиться': 628,
#  'принять': 629,
#  'понять': 630,
#  'простить:': 631,
#  'есть': 632,
#  'любить': 633,
#  'вместе': 634,
#  'Алесей': 635,
#  'общем': 636,
#  'ваших': 637,
#  'эта': 638,
#  'книжка': 639,
#  'никогда': 640,
#  'читали': 641,
#  'счастливый': 642,
#  'Вас': 643,
#  'ждет': 644,
#  'несказанное': 645,
#  'удовольствие': 646,
#  'книжку': 647,
#  'Не': 648,
#  'работает': 649,
#  'счастье': 650,
#  'неизбежно': 651,
#  'P': 652,
#  'S': 653,
#  'Только': 654,
#  'читайте': 655,
#  'ночь': 656,
#  'мужья': 657,
#  '(и': 658,
#  'жены)': 659,
#  'настолько': 660,
#  'устойчивы': 661,
#  'Р': 662,
#  'Игорь': 663,
#  'тебя': 664,
#  'Спасибо': 665,
#  'тебе': 666,
#  'знаете': 667,
#  'смейте': 668,
#  'срываться': 669,
#  'крючка': 670,
#  'Ладно': 671,
#  'пополам»': 672,
#  'Юлия': 673,
#  'Меньшова': 674,
#  'актриса': 675,
#  'телеведущая': 676,
#  '«Не': 677,
#  'огромной': 678,
#  'буквы': 679,
#  '«П»': 680,
#  '«сетевой': 681,
#  'писатель»': 682,
#  '(произносится': 683,
#  'усмешкой)': 684,
#  'блогер': 685,
#  'умная': 686,
#  'веселая': 687,
#  'наблюдательная': 688,
#  'молодая': 689,
#  'женщина': 690,
#  'собрала': 691,
#  'заметки': 692,
#  'Насмешка': 693,
#  'над': 694,
#  'собой': 695,
#  'тихое': 696,
#  'изумление': 697,
#  'перед': 698,
#  'абсурдом': 699,
#  'мира': 700,
#  'может': 701,
#  'быть': 702,
#  'привлекательнее': 703,
#  'такой': 704,
#  'авторской': 705,
#  'интонации': 706,
#  'Петровну': 707,
#  'со': 708,
#  'времен': 709,
#  'Поскольку': 710,
#  'обе': 711,
#  'работаем': 712,
#  'кино': 713,
#  'несколько': 714,
#  'порывалась': 715,
#  'предложить': 716,
#  'сотрудничество': 717,
#  'решалась': 718,
#  'познакомиться': 719,
#  'кумир': 720,
#  'должен': 721,
#  'оставаться': 722,
#  'кумиром': 723,
#  'кумир»': 724,
#  'Авдотья': 725,
#  'Смирнова': 726,
#  'кинорежиссер': 727,
#  'сценарист': 728,
#  '«Завидую': 729,
#  'языку': 730,
#  'можно': 731,
#  'коротко': 732,
#  'других': 733,
#  'чтото': 734,
#  'одно': 735,
#  'Ни': 736,
#  'тени': 737,
#  'позерства': 738,
#  'ни': 739,
#  'грамма': 740,
#  'самолюбования': 741,
#  'Абсолютный': 742,
#  'вкус': 743,
#  'иммунитет': 744,
#  'пошлости': 745,
#  'единой': 746,
#  'банальности': 747,
#  'Так': 748,
#  'наверное': 749,
#  'высший': 750,
#  'разум': 751,
#  'Вне': 752,
#  'пола': 753,
#  'вне': 754,
#  'добра': 755,
#  'зла': 756,
#  'Просто': 757,
#  'взгляд': 758,
#  'сверху': 759,
#  'емкий': 760,
#  'надпись': 761,
#  'камне': 762,
#  'Смеешься': 763,
#  'дважды': 764,
#  'парадоксом': 765,
#  'восхищения': 766,
#  'парадокс': 767,
#  'подан': 768,
#  'Интернет': 769,
#  'убил': 770,
#  'он': 771,
#  'же': 772,
#  'породил': 773,
#  'которая': 774,
#  'интересней': 775,
#  'всего': 776,
#  'ютуба': 777,
#  'Перед': 778,
#  'цепенеют': 779,
#  'искусствоведы': 780,
#  'Издаться': 781,
#  'успела': 782,
#  'подражают': 783,
#  'обожают': 784,
#  'боятся': 785,
#  'Тьма': 786,
#  'писателей': 787,
#  'станет': 788,
#  'третьим': 789,
#  'сортом': 790,
#  'новый': 791,
#  'сорт': 792,
#  'вас': 793,
#  'Первая': 794,
#  'Казанцевой': 795,
#  'Лети': 796,
#  'ужасная»': 797,
#  'Слава': 798,
#  'Сэ': 799,
#  '«Для': 800,
#  '«Живом': 801,
#  'Журнале»': 802,
#  'хохотал': 803,
#  'плакал': 804,
#  'пересказывал': 805,
#  'друзьям': 806,
#  'истории': 807,
#  'телефон': 808,
#  'Антона': 809,
#  'Городецкого': 810,
#  'Митю': 811,
#  'бобра': 812,
#  'которого': 813,
#  'перекрасить': 814,
#  'для': 815,
#  'съемок': 816,
#  'лошадей': 817,
#  'которых': 818,
#  'научили': 819,
#  'прыгать': 820,
#  'стену': 821,
#  'отличный': 822,
#  'способ': 823,
#  'освежить': 824,
#  'их': 825,
#  'памяти': 826,
#  'захохотать': 827,
#  'заплакать': 828,
#  'какойто': 829,
#  'причине': 830,
#  'завидую': 831,
#  'правда': 832,
#  'хорошая»': 833,
#  'Яна': 834,
#  'Вагнер': 835,
#  'безответно': 836,
#  'тексты': 837,
#  'однажды': 838,
#  'незнакомому': 839,
#  'человеку': 840,
#  'классная': 841,
#  '(трезвый)': 842,
#  'отреагировала': 843,
#  'единственно': 844,
#  'возможным': 845,
#  'образом:': 846,
#  'прочитала': 847,
#  'обижаюсь': 848,
#  'жаль': 849,
#  'реже': 850,
#  'желаю': 851,
#  'плохого': 852,
#  'чаще': 853,
#  'Например': 854,
#  'пусть': 855,
#  'Димы': 856,
#  'найдется': 857,
#  'четыре': 858,
#  'семьи': 859,
#  'них': 860,
#  'гарем': 861,
#  'Ну': 862,
#  'худой': 863,
#  'конец': 864,
#  'ремонт': 865,
#  'Да': 866,
#  'ремонт»': 867,
#  'Гуриев': 868,
#  '«Каждый': 869,
#  'прочитав': 870,
#  'пост': 871,
#  'хотелось': 872,
#  'немедля': 873,
#  'найти': 874,
#  'подарить': 875,
#  'цветы': 876,
#  'обнимать': 877,
#  'Кроме': 878,
#  'чудесного': 879,
#  'юмора': 880,
#  'иронии': 881,
#  'слога': 882,
#  'острого': 883,
#  'взгляда': 884,
#  'этих': 885,
#  'текстах': 886,
#  'обезоруживающая': 887,
#  'обрушивающаяся': 888,
#  'любовь': 889,
#  'жизни': 890,
#  'Радость': 891,
#  'жить': 892,
#  'Любить': 893,
#  'Парить': 894,
#  'Каждый': 895,
#  'заканчивались': 896,
#  'обнаруживала': 897,
#  'себя': 898,
#  'настроении': 899,
#  'близком': 900,
#  'полетному': 901,
#  'высока': 902,
#  'концентрация': 903,
#  'счастья': 904,
#  'текстах»': 905,
#  'Алиса': 906,
#  'Гребенщикова': 907,
#  '«Отличная': 908,
#  'отличное': 909,
#  'издательство': 910,
#  'LiveBook:': 911,
#  'здорово': 912,
#  'сошлись': 913,
#  'Эта': 914,
#  'увесистая': 915,
#  'напоминает': 916,
#  'машину': 917,
#  'времени': 918,
#  'Открываешь': 919,
#  'глазами': 920,
#  'бескрайние': 921,
#  'поля': 922,
#  'длинные': 923,
#  'ветки': 924,
#  'переписки': 925,
#  'ночи': 926,
#  'сна': 927,
#  'будто': 928,
#  'множества': 929,
#  'отдаливших': 930,
#  'прежних': 931,
#  'нас': 932,
#  'нынешних': 933,
#  'ваша': 934,
#  'молодость': 935,
#  'прошла': 936,
#  'чтения': 937,
#  'Казанцевских': 938,
#  'дневников': 939,
#  'ним': 940,
#  'приобщиться': 941,
#  'благо': 942,
#  'автор': 943,
#  'жив': 944,
#  'здоров': 945,
#  'полон': 946,
#  'любви': 947,
#  'миру': 948,
#  'Заразительной': 949,
#  'любви»': 950,
#  'Сергей': 951,
#  'Вересков': 952,
#  'литературный': 953,
#  'критик': 954,
#  'Издательство': 955,
#  'предложило': 956,
#  'собрать': 957,
#  'мои': 958,
#  'записи': 959,
#  'интернета': 960,
#  'ужас': 961,
#  'переполняет': 962,
#  'Села': 963,
#  'перечитала': 964,
#  'года': 965,
#  'Стыд': 966,
#  'выедает': 967,
#  'Вопросы': 968,
#  'бьются': 969,
#  'череп': 970,
#  'изнутри': 971,
#  'могла': 972,
#  'Что': 973,
#  'несла': 974,
#  'Зачем': 975,
#  'весь': 976,
#  'бред': 977,
#  'женился': 978,
#  'предпосылки': 979,
#  'были': 980,
#  'жила': 981,
#  'Пирожком': 982,
#  'крупная': 983,
#  'меховая': 984,
#  'игрушка': 985,
#  'затопила': 986,
#  'этажей': 987,
#  'Пирожок': 988,
#  'сидел': 989,
#  'полу': 990,
#  'впитал': 991,
#  'много': 992,
#  'воды': 993,
#  'благодаря': 994,
#  'хотя': 995,
#  'подвал': 996,
#  'диваном': 997,
#  'Митей': 998,
#  'сделали': 999,
#  ...}

# %%
window_size = 2
idx_pairs = []
# for each sentence
for sentence in tokenized_data:
    indices = [word2idx[word] for word in sentence]
    # for each word, threated as center word
    for center_word_pos in range(len(indices)):
        # for each window position
        for w in range(-window_size, window_size + 1):
            context_word_pos = center_word_pos + w
            # make soure not jump out sentence
            if context_word_pos < 0 or context_word_pos >= len(indices) or center_word_pos == context_word_pos:
                continue
            context_word_idx = indices[context_word_pos]
            idx_pairs.append((indices[center_word_pos], context_word_idx))

idx_pairs = np.array(idx_pairs) # it will be useful to have this as numpy array

# %%
idx_pairs[:1000]
# Out:
# array([[  0,   1],
#        [  1,   0],
#        [  2,   3],
#        ...,
#        [205, 204],
#        [205,  31],
#        [205, 206]])

# %%
def get_input_layer(words_idx):
    x = torch.zeros(words_idx.shape[0], vocabulary_size).float()
    x[list(range(0, words_idx.shape[0])), words_idx] = 1.
    return x

# %%
embedding_dims = 5

class MyModule(nn.Module):
    def __init__(self):
        super().__init__()
        self.input_line = nn.Linear(vocabulary_size, embedding_dims)
        self.output_line = nn.Linear(embedding_dims, vocabulary_size)
        
    def forward(self, X):
        X = F.relu(self.input_line(X))
        return F.softmax(self.output_line(X))

# %%
eta = 0.001
epochs = 1010
model = MyModule()
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=eta)

# %%
losses = []
batch_size = 59
for epoch in range(epochs):
  loss_val = []
  for batch in range(0,idx_pairs.shape[0], batch_size):
    x = get_input_layer(idx_pairs[batch:batch+batch_size, 0])
    target = torch.from_numpy(np.array([idx_pairs[batch:batch+batch_size, 1]]))

    y = model(x)
    loss = loss_function(y, target.view(-1))
    loss_val.append(loss.item())
    loss.backward()
    optimizer.step()

    model.zero_grad()

  losses.append(np.mean(loss_val))
  if epo % 10 == 0:    
        print(f'Loss at epo {epo}: {np.mean(loss_val)}')
# Out:
# <ipython-input-69-02e0ab43648f>:11: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(self.output_line(X))
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-71-17c40094d7c1> in <module>
#       8
#       9     y = model(x)
# ---> 10     loss = loss_function(y, target.view(-1))
#      11     loss_val.append(loss.item())
#      12     loss.backward()
#
# I:\kh\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# I:\kh\lib\site-packages\torch\nn\modules\loss.py in forward(self, input, target)
#     945
#     946     def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 947         return F.cross_entropy(input, target, weight=self.weight,
#     948                                ignore_index=self.ignore_index, reduction=self.reduction)
#     949
#
# I:\kh\lib\site-packages\torch\nn\functional.py in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction)
#    2420     if size_average is not None or reduce is not None:
#    2421         reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 2422     return nll_loss(log_softmax(input, 1), target, weight, None, ignore_index, None, reduction)
#    2423
#    2424
#
# I:\kh\lib\site-packages\torch\nn\functional.py in nll_loss(input, target, weight, size_average, ignore_index, reduce, reduction)
#    2216                          .format(input.size(0), target.size(0)))
#    2217     if dim == 2:
# -> 2218         ret = torch._C._nn.nll_loss(input, target, weight, _Reduction.get_enum(reduction), ignore_index)
#    2219     elif dim == 4:
#    2220         ret = torch._C._nn.nll_loss2d(input, target, weight, _Reduction.get_enum(reduction), ignore_index)
#
# RuntimeError: expected scalar type Long but found Int
